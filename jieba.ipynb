# %%
pip install jieba
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install jieba
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more informations on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
#encoding=utf-8
import jieba

sentence = "獨立音樂需要大家一起來推廣，歡迎加入我們的行列！"
print ("Input：", sentence)
words = jieba.cut(sentence, cut_all=False)
print ("Output 精確模式 Full Mode：")
for word in words:
    print (word)

sentence = "独立音乐需要大家一起来推广，欢迎加入我们的行列！"
print ("Input：", sentence)
words = jieba.cut(sentence, cut_all=False)
print ("Output 精確模式 Full Mode：")
for word in words:
    print (word)
# Out:
# Building prefix dict from the default dictionary ...
# Input： 獨立音樂需要大家一起來推廣，歡迎加入我們的行列！
# Output 精確模式 Full Mode：
# Dumping model to file cache C:\Users\user\AppData\Local\Temp\jieba.cache
# Loading model cost 0.793 seconds.
# Prefix dict has been built succesfully.
# 獨立
# 音樂
# 需要
# 大家
# 一起
# 來
# 推廣
# ，
# 歡迎
# 加入
# 我們
# 的
# 行列
# ！
# Input： 独立音乐需要大家一起来推广，欢迎加入我们的行列！
# Output 精確模式 Full Mode：
# 独立
# 音乐
# 需要
# 大家
# 一
# 起来
# 推广
# ，
# 欢迎
# 加入
# 我们
# 的
# 行列
# ！

# %%
#encoding=utf-8
import jieba

jieba.set_dictionary('dict.txt.big')

content = open('lyric.txt', 'rb').read()

print ("Input：", content)

words = jieba.cut(content, cut_all=False)

print ("Output 精確模式 Full Mode：")
for word in words:
    print (word)
# Out:
# Building prefix dict from C:\Users\user\dict.txt.big ...
# Input： b'\xe6\x88\x91\xe6\xb2\x92\xe6\x9c\x89\xe5\xbf\x83\n\xe6\x88\x91\xe6\xb2\x92\xe6\x9c\x89\xe7\x9c\x9f\xe5\xaf\xa6\xe7\x9a\x84\xe8\x87\xaa\xe6\x88\x91\n\xe6\x88\x91\xe5\x8f\xaa\xe6\x9c\x89\xe6\xb6\x88\xe7\x98\xa6\xe7\x9a\x84\xe8\x87\x89\xe5\xad\x94\n\xe6\x89\x80\xe8\xac\x82\xe8\xbb\x9f\xe5\xbc\xb1\n\xe6\x89\x80\xe8\xac\x82\xe7\x9a\x84\xe9\xa0\x86\xe5\xbe\x9e\xe4\xb8\x80\xe5\x90\x91\xe6\x98\xaf\xe6\x88\x91\n\xe7\x9a\x84\xe5\xba\xa7\xe5\x8f\xb3\xe9\x8a\x98\n\n\xe8\x80\x8c\xe6\x88\x91\n\xe6\xb2\x92\xe6\x9c\x89\xe9\x82\xa3\xe6\xb5\xb7\xe6\xb4\x8b\xe7\x9a\x84\xe5\xaf\xac\xe9\x97\x8a\n\xe6\x88\x91\xe5\x8f\xaa\xe8\xa6\x81\xe7\x86\xb1\xe6\x83\x85\xe7\x9a\x84\xe6\x92\xab\xe6\x91\xb8\n\xe6\x89\x80\xe8\xac\x82\xe7\xa9\xba\xe6\xb4\x9e\n\xe6\x89\x80\xe8\xac\x82\xe4\xb8\x8d\xe5\xae\x89\xe5\x85\xa8\xe6\x84\x9f\xe6\x98\xaf\xe6\x88\x91\n\xe7\x9a\x84\xe5\xa2\x93\xe8\xaa\x8c\xe9\x8a\x98\n\n\xe8\x80\x8c\xe4\xbd\xa0\n\xe6\x98\xaf\xe5\x90\xa6\xe5\x92\x8c\xe6\x88\x91\xe4\xb8\x80\xe8\x88\xac\xe6\x80\xaf\xe6\x87\xa6\n\xe6\x98\xaf\xe5\x90\xa6\xe5\x92\x8c\xe6\x88\x91\xe4\xb8\x80\xe8\x88\xac\xe7\x9f\xaf\x
# 的
# 自我
#
#
# 我
# 只有
# 消瘦
# 的
# 臉孔
#
#
# 所謂
# 軟弱
#
#
# 所謂
# 的
# 順從
# 一向
# 是
# 我
#
#
# 的
# 座右銘
#
#
#
#
# 而
# 我
#
#
# 沒有
# 那
# 海洋
# 的
# 寬闊
#
#
# 我
# 只要
# 熱情
# 的
# 撫摸
#
#
# 所謂
# 空洞
#
#
# 所謂
# 不安全感
# 是
# 我
#
#
# 的
# 墓誌銘
#
#
#
#
# 而
# 你
#
#
# 是否
# 和
# 我
# 一般
# 怯懦
#
#
# 是否
# 和
# 我
# 一般
# 矯作
#
#
# 和
# 我
# 一般
# 囉唆
#
#
#
#
# 而
# 你
#
#
# 是否
# 和
# 我
# 一般
# 退縮
#
#
# 是否
# 和
# 我
# 一般
# 肌迫
#
#
# 一般
# 地
# 困惑
#
#
#
#
# 我
# 沒有
# 力
#
#
# 我
# 沒有
# 滿腔
# 的
# 熱火
#
#
# 我
# 只有
# 滿肚
# 的
# 如果
#
#
# 所謂
# 勇氣
#
#
# 所謂
# 的
# 認同感
# 是
# 我
#
#
# 隨便說說
#
#
#
#
# 而
# 你
#
#
# 是否
# 和
# 我
# 一般
# 怯懦
#
#
# 是否
# 和
# 我
# 一般
# 矯作
#
#
# 是否
# 對
# 你
# 來說
#
#
# 只是
# 一場
# 遊戲
#
#
# 雖然
# 沒有
# 把握
#
#
#
#
# 而
# 你
#
#
# 是否
# 和
# 我
# 一般
# 退縮
#
#
# 是否
# 和
# 我
# 一般
# 肌迫
#
#
# 是否
# 對
# 你
# 來說
#
#
# 只是
# 逼不得已
#
#
# 雖然
# 沒有
# 藉口

# %%
# encoding=utf-8
import jieba

jieba.set_dictionary('dict.txt.big')

seg_list = jieba.cut("塵世中一個迷途小書僮")
print(" / ".join(seg_list))

seg_list = jieba.cut("我們在野生動物園玩")
print(" / ".join(seg_list)) # 歧異詞辨識

seg_list = jieba.cut("林志傑是結巴PHP的作者")
print(" / ".join(seg_list)) # 新詞辨識
# Out:
# Building prefix dict from C:\Users\user\dict.txt.big ...
# Loading model from cache C:\Users\user\AppData\Local\Temp\jieba.ua7677c818aa16337f448e65eab47ca3f.cache
# Loading model cost 1.212 seconds.
# Prefix dict has been built succesfully.
# 塵世 / 中 / 一個 / 迷途 / 小 / 書僮
# 我們 / 在 / 野生 / 動物園 / 玩
# 林志傑 / 是 / 結巴 / PHP / 的 / 作者

# %%
# encoding=utf-8
import jieba

jieba.set_dictionary('dict.txt.big')

seg_list = jieba.cut("下雨天留客天留我不留")
print(" / ".join(seg_list))

seg_list = jieba.cut("海水朝朝朝朝朝朝朝落；浮雲長長長長長長長消。")
print(" / ".join(seg_list))

seg_list = jieba.cut("海水潮，朝朝潮，朝潮朝落；浮雲長，常常長，常長常消。")
print(" / ".join(seg_list))
# Out:
# Building prefix dict from C:\Users\user\dict.txt.big ...
# Loading model from cache C:\Users\user\AppData\Local\Temp\jieba.ua7677c818aa16337f448e65eab47ca3f.cache
# Loading model cost 1.231 seconds.
# Prefix dict has been built succesfully.
# 下雨天 / 留客 / 天留 / 我 / 不留
# 海水 / 朝朝 / 朝朝朝 / 朝朝落 / ； / 浮雲 / 長長 / 長長 / 長長 / 長 / 消 / 。
# 海水 / 潮 / ， / 朝朝潮 / ， / 朝潮 / 朝落 / ； / 浮雲 / 長 / ， / 常常 / 長 / ， / 常長 / 常消 / 。
